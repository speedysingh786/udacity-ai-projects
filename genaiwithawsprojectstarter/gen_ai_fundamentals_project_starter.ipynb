# %% [markdown]
# # Project: Teaching an LLM to Reason
#
# In this project, you will teach an LLM to use step-by-step reasoning to answer the question: "How many X's are there in the word Y?"
#
# Counting letters in a word is a surprisingly complex task for an LLM. Just as human beings would not be able to answer such a question for longer words without breaking down the word into its individual letters and then counting them, LLMs cannot be similarly expected to be able to respond without using smaller reasoning steps.
#
# For example, to count the number of o's in the word room, one could use the following reasoning:
#
# ```
# Question: How many of the letter "o" are there in the word "room"
# Answer: 2
# Response:
#
# <reasoning>
# Letter-by-letter spelling:
# 1. r - 0 o's so far
# 2. o - 1 o's so far
# 3. o - 2 o's so far
# 4. m - 2 o's so far
#
# The letter "o" appears 2 times in the word "room".
# </reasoning>
# <answer>
# 2
# </answer>
# ```
#
# In this project we will use the reinforcement learning method GRPO (Group Relative Policy Optimization, of DeepSeek fame) to take a large language model that has been fine-tuned for following instructions and teach it how to break a word down into its letters and then count the requested letter.
#
# We will complete the following steps:
#
# * Set up the notebook
# * Create a letter-counting dataset
# * Create the reward functions
# * Train the model
# * View the results
#
# NOTE: This notebook will have you focus on several important aspects of training a GPRO model using LoRA:
#
# 1. Configuring LoRA adapters for parameter-efficient fine tuning
# 2. Selecting reward functions that help the model efficiently find its way to the correct answer (also called reward shaping)
# 3. Finding hyperparameters that help the model increase the rewards earned more quickly and reliably
# 4. Learning how to start with smaller experiments and to work your way up to longer experiments.

# %% [markdown]
# ## Set up the notebook
#
# We'll install dependencies needed for the project, namely `unsloth` and `vllm`, which are useful for fine-tuning LLMs with even just 15GB of VRAM.

# %%
# Load ipython-autotime to see how long each cell take to run
# No changes needed in this cell

#!pip install -q ipython-autotime
# !pip install unsloth
# %load_ext autotime
# Out:
# Requirement already satisfied: unsloth in ./.venv/lib/python3.11/site-packages (2026.3.3)
# Requirement already satisfied: unsloth_zoo>=2026.3.1 in ./.venv/lib/python3.11/site-packages (from unsloth) (2026.3.1)
# Requirement already satisfied: wheel>=0.42.0 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.45.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from unsloth) (25.0)
# Requirement already satisfied: torch>=2.4.0 in ./.venv/lib/python3.11/site-packages (from unsloth) (2.7.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.11/site-packages (from unsloth) (0.22.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from unsloth) (2.2.6)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.11/site-packages (from unsloth) (7.1.0)
# Requirement already satisfied: tyro in ./.venv/lib/python3.11/site-packages (from unsloth) (0.9.32)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.11/site-packages (from unsloth) (6.32.1)
# Requirement already satisfied: bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.49.2)
# Requirement already satisfied: sentencepiece>=0.2.0 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.2.1)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 in ./.venv/lib/python3.11/site-packages (from unsloth) (3.6.0)
# Requirement already satisfied: accelerate>=0.34.1 in ./.venv/lib/python3.11/site-packages (from unsloth) (1.10.1)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.18.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.35.0)
# Requirement already satisfied: hf_transfer in ./.venv/lib/python3.11/site-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in ./.venv/lib/python3.11/site-packages (from unsloth) (0.35.1)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.2.0,>=4.51.3 in ./.venv/lib/python3.11/site-packages (from unsloth) (4.55.4)
# Requirement already satisfied: trl!=0.19.0,<=0.24.0,>=0.18.2 in ./.venv/lib/python3.11/site-packages (from unsloth) (0.22.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.3.8)
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.32.5)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in ./.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.11/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.12.15)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.11/site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.2.0,>=4.51.3->unsloth) (2025.9.18)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.venv/lib/python3.11/site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.2.0,>=4.51.3->unsloth) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.11/site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.2.0,>=4.51.3->unsloth) (0.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.11/site-packages (from huggingface_hub>=0.34.0->unsloth) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.11/site-packages (from huggingface_hub>=0.34.0->unsloth) (1.1.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.20.1)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.10)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: torchao>=0.13.0 in ./.venv/lib/python3.11/site-packages (from unsloth_zoo>=2026.3.1->unsloth) (0.16.0)
# Requirement already satisfied: cut_cross_entropy in ./.venv/lib/python3.11/site-packages (from unsloth_zoo>=2026.3.1->unsloth) (25.1.1)
# Requirement already satisfied: pillow in ./.venv/lib/python3.11/site-packages (from unsloth_zoo>=2026.3.1->unsloth) (11.3.0)
# Requirement already satisfied: msgspec in ./.venv/lib/python3.11/site-packages (from unsloth_zoo>=2026.3.1->unsloth) (0.19.0)
# Requirement already satisfied: importlib_metadata in ./.venv/lib/python3.11/site-packages (from diffusers->unsloth) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.11/site-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.17.0)
# Requirement already satisfied: docstring-parser>=0.15 in ./.venv/lib/python3.11/site-packages (from tyro->unsloth) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in ./.venv/lib/python3.11/site-packages (from tyro->unsloth) (14.1.0)
# Requirement already satisfied: shtab>=1.5.6 in ./.venv/lib/python3.11/site-packages (from tyro->unsloth) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in ./.venv/lib/python3.11/site-packages (from tyro->unsloth) (4.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.11/site-packages (from rich>=11.1.0->tyro->unsloth) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.11/site-packages (from rich>=11.1.0->tyro->unsloth) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth) (0.1.2)
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 687 ms (started: 2026-03-07 02:25:57 -07:00)

# %%
# Verify we have enough GPU memory to run this project (at least 15360MiB)
# No changes needed in this cell

# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi
# time: 255 ms (started: 2026-03-07 02:25:28 -07:00)

# %%
# Load the `Qwen 2.5 3B Instruct`, and set parameters for the project
# The first time unsloth is imported, it will do its magic and patch the modules
# it works with. This may 2-5 minutes.
# TODO: Fill in the missing parts marked with **********

import unsloth

from unsloth import FastLanguageModel
import torch

max_seq_length = 384  # Increase if you get errors about the sequence length

# Set the LoRA rank to an appropriate value
# Read about setting LoRA rank:
# https://docs.unsloth.ai/get-started/fine-tuning-llms-guide/lora-hyperparameters-guide
lora_rank = 16  # Explain your choice - Since the env is configured with 16GB VRAM, higher rank uses more memory

# Load the Instruct model in 4-bit mode
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="Qwen/Qwen2.5-3B-Instruct",
    max_seq_length=max_seq_length,
    load_in_4bit=True,  # We'll use quantization!
    fast_inference=True,  # This uses vllm for faster inference
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.5,  # You can reduce this if you get an memory error
)

model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,
    target_modules=[
        # Read about choosing adapters for LoRA:
        # https://docs.unsloth.ai/get-started/fine-tuning-llms-guide/lora-hyperparameters-guide
        # Choose the target modules/adapters for your LoRA model
        "q_proj", # Explain your choice - changes model attention behavior and strong baseline 
        "k_proj","v_proj","o_proj"
       
    ],
    lora_alpha=lora_rank,
    use_gradient_checkpointing="unsloth",  # Unsloth enables longer contexts
    # See: https://github.com/unslothai/unsloth
)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 6
#       1 # Load the `Qwen 2.5 3B Instruct`, and set parameters for the project
#       2 # The first time unsloth is imported, it will do its magic and patch the modules
#       3 # it works with. This may 2-5 minutes.
#       4 # TODO: Fill in the missing parts marked with **********
# ----> 6 import unsloth
#       8 from unsloth import FastLanguageModel
#       9 import torch
#
# File ~/ai/projects/udacity-ai-projects/.venv/lib/python3.11/site-packages/unsloth/__init__.py:105
#      93         print(
#      94             "Unsloth: Please update Unsloth and Unsloth-Zoo to the latest version!\n"
#      95             "Do this via `pip install --upgrade --force-reinstall --no-cache-dir --no-deps unsloth unsloth_zoo`"
#      96         )
#      97         # if os.environ.get("UNSLOTH_DISABLE_AUTO_UPDATES", "0") == "0":
#      98         #     try:
#      99         #         os.system("pip install --upgrade --no-cache-dir --no-deps unsloth_zoo")
#    (...)    103         #         except:
#     104         #             raise ImportError("Unsloth: Please update unsloth_zoo via `pip install --upgrade --no-cache-dir --no-deps unsloth_zoo`")
# --> 105     import unsloth_zoo
#     106 except PackageNotFoundError:
#     107     raise ImportError(
#     108         f"Unsloth: Please install unsloth_zoo via `pip install unsloth_zoo` then retry!"
#     109     )
#
# File ~/ai/projects/udacity-ai-projects/.venv/lib/python3.11/site-packages/unsloth_zoo/__init__.py:220
#     217 del logging, torchao_logger, HideLoggingMessage
#     219 # Get device types and other variables
# --> 220 from .device_type import (
#     221     is_hip,
#     222     get_device_type,
#     223     DEVICE_TYPE,
#     224     DEVICE_TYPE_TORCH,
#     225     DEVICE_COUNT,
#     226     ALLOW_PREQUANTIZED_MODELS,
#     227 )
#     228 IS_HIP_RUNTIME = (DEVICE_TYPE == "hip") or bool(is_hip())
#     230 # Torch >= 2.9 uses PYTORCH_ALLOC_CONF and treats legacy per-backend vars as deprecated.
#
# File ~/ai/projects/udacity-ai-projects/.venv/lib/python3.11/site-packages/unsloth_zoo/device_type.py:231
#     229     raise NotImplementedError("Unsloth currently only works on NVIDIA, AMD and Intel GPUs.")
#     230 pass
# --> 231 DEVICE_TYPE : str = get_device_type()
#     232 # HIP fails for autocast and other torch functions. Use CUDA instead
#     233 DEVICE_TYPE_TORCH = DEVICE_TYPE
#
# File ~/ai/projects/udacity-ai-projects/.venv/lib/python3.11/site-packages/unsloth_zoo/device_type.py:229, in get_device_type()
#     227 if amd_hint is not None:
#     228     raise NotImplementedError(amd_hint)
# --> 229 raise NotImplementedError("Unsloth currently only works on NVIDIA, AMD and Intel GPUs.")
#
# NotImplementedError: Unsloth currently only works on NVIDIA, AMD and Intel GPUs.
# time: 5.91 s (started: 2026-03-07 02:25:31 -07:00)

# %%
# First, let's see what happens when we have a blank system prompt
# No changes needed in this cell
SYSTEM_PROMPT = """"""
USER_PROMPT = 'How many of the letter "g" are there in the word "engage"'

# Convert the chat messages to a single string so the model can complete it
text_for_completion = tokenizer.apply_chat_template(
    conversation=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {
            "role": "user",
            "content": USER_PROMPT,
        },
    ],
    tokenize=False,
    add_generation_prompt=True,
)

from vllm import SamplingParams

# Set the LLM sampling parameters
sampling_params = SamplingParams(
    temperature=0.8,
    top_p=0.95,
    max_tokens=2048,
)

# Generate the text completion
output = (
    model.fast_generate(
        [text_for_completion],
        sampling_params=sampling_params,
        lora_request=None,
    )[0]
    .outputs[0]
    .text
)

# Print the text input for the model and the model's output
print("=== TEXT FOR COMPLETION ===")
print(text_for_completion)
print("=== GENERATED OUTPUT ===")
print(output)
# Out:
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 975.87it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.51it/s, est. speed input: 43.88 toks/s, output: 22.70 toks/s]
# === TEXT FOR COMPLETION ===
# <|im_start|>system
# <|im_end|>
# <|im_start|>user
# How many of the letter "g" are there in the word "engage"<|im_end|>
# <|im_start|>assistant
#
# === GENERATED OUTPUT ===
# In the word "engage", there is only one letter "g".

# %% [markdown]
# Without any prompting the model will generate an output such as this:
#
# ```
# === GENERATED OUTPUT ===
# There is one letter "g" in the word "engage".
# ```
#
# Now let's work on the system prompt to help the model break this problem down into steps, which might help it get the right answer (2 `g`'s in `engage`)

# %%
# Let's work on a new system prompt that will help the model break this problem
# down into steps, for example, using "letter-by-letter" spelling.
# TODO: Fill in the missing parts marked with **********

# Use a CoT prompt with at least one example
SYSTEM_PROMPT = """ Act as a helpful assitant that counts how many time a letter appears in a give word 
Instructions
0. Before answering write your step-by-step reasoning
1. Break the word into letter-by-letter
2. Identify the each occurrences of the target letter
3. Count the occurrences explicitly
4. state the final answer clearly as number 

For example, to count the number of o's in the word room, one could use the following reasoning:

```
Question: How many of the letter "o" are there in the word "room"
Answer: 2
Response:

<reasoning>
Letter-by-letter spelling:
1. r - 0 o's so far
2. o - 1 o's so far
3. o - 2 o's so far
4. m - 2 o's so far

The letter "o" appears 2 times in the word "room".
</reasoning>
<answer>
2
</answer>
``` """


USER_PROMPT = 'How many of the letter "g" are there in the word "engage"'

# Convert the chat messages to a single string so the model can complete it
text_for_completion = tokenizer.apply_chat_template(
    conversation=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {
            "role": "user",
            "content": USER_PROMPT,
        },
    ],
    tokenize=False,
    add_generation_prompt=True,
)

from vllm import SamplingParams

# Set the LLM sampling parameters
sampling_params = SamplingParams(
    temperature=0.8,
    top_p=0.95,
    max_tokens=2048,
)

# Generate the text completion
output = (
    model.fast_generate(
        [text_for_completion],
        sampling_params=sampling_params,
        lora_request=None,
    )[0]
    .outputs[0]
    .text
)

# Print the text input for the model and the model's output
print("=== TEXT FOR COMPLETION ===")
print(text_for_completion)
print("=== GENERATED OUTPUT ===")
print(output)
# Out:
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 570.73it/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.96s/it, est. speed input: 77.87 toks/s, output: 38.60 toks/s]
# === TEXT FOR COMPLETION ===
# <|im_start|>system
#  Act as a helpful assitant that counts how many time a letter appears in a give word
# Instructions
# 0. Before answering write your step-by-step reasoning
# 1. Break the word into letter-by-letter
# 2. Identify the each occurrences of the target letter
# 3. Count the occurrences explicitly
# 4. state the final answer clearly as number
#
# For example, to count the number of o's in the word room, one could use the following reasoning:
#
# ```
# Question: How many of the letter "o" are there in the word "room"
# Answer: 2
# Response:
#
# <reasoning>
# Letter-by-letter spelling:
# 1. r - 0 o's so far
# 2. o - 1 o's so far
# 3. o - 2 o's so far
# 4. m - 2 o's so far
#
# The letter "o" appears 2 times in the word "room".
# </reasoning>
# <answer>
# 2
# </answer>
# ``` <|im_end|>
# <|im_start|>user
# How many of the letter "g" are there in the word "engage"<|im_end|>
# <|im_start|>assistant
#
# === GENERATED OUTPUT ===
# <reasoning>
# Letter-by-letter spelling:
# 1. a - 0 g's so far
# 2. n - 0 g's so far
# 3. g - 1 g's so far
# 4. e - 1 g's so far
# 5. a - 1 g's so far
# 6. n - 1 g's so far
# 7. g - 2 g's so far
#
# The letter "g" appears 2 times in the word "engage".
# </reasoning>
# <answer>
# 2
# </answer>

# %% [markdown]
# Did your new prompt get the right answer? Did the model follow all of your instructions?
#
# Maybe yes, maybe no. Either way, we'll want the model to reliably complete this challenge. So let's use GRPO to help it!

# %% [markdown]
# ## Create a letter-counting dataset
#
# To train a model, we'll first need to create a dataset. We'll use the HuggingFace `datasets` package.

# %%
# Create a list of words of different lengths
# No changes are needed in this cell.

ALL_WORDS = [
    "idea",
    "glow",
    "rust",
    "maze",
    "echo",
    "wisp",
    "veto",
    "lush",
    "gaze",
    "knit",
    "fume",
    "plow",
    "void",
    "oath",
    "grim",
    "crisp",
    "lunar",
    "fable",
    "quest",
    "verge",
    "brawn",
    "elude",
    "aisle",
    "ember",
    "crave",
    "ivory",
    "mirth",
    "knack",
    "wryly",
    "onset",
    "mosaic",
    "velvet",
    "sphinx",
    "radius",
    "summit",
    "banner",
    "cipher",
    "glisten",
    "mantle",
    "scarab",
    "expose",
    "fathom",
    "tavern",
    "fusion",
    "relish",
    "lantern",
    "enchant",
    "torrent",
    "capture",
    "orchard",
    "eclipse",
    "frescos",
    "triumph",
    "absolve",
    "gossipy",
    "prelude",
    "whistle",
    "resolve",
    "zealous",
    "mirage",
    "aperture",
    "sapphire",
]

print(len(ALL_WORDS))

ALL_WORDS[:10]
# Out:
# 62
# ['idea',
#  'glow',
#  'rust',
#  'maze',
#  'echo',
#  'wisp',
#  'veto',
#  'lush',
#  'gaze',
#  'knit']

# %%
# Create the dataset as a Hugging Face Dataset using Dataset.from_generator
# No changes needed in this cell

from datasets import Dataset
import random


# Go through the letters from the words (as well as letters not in the words),
# and create a labelled dataset with all the different combinations.
# For example for the word gaze:
# 1. How many i's are in idea? <-- count should be 1
# 2. How many d's are in idea? <-- count should be 1
# 3. How many e's are in idea? <-- count should be 1
# 4. How many a's are in idea? <-- count should be 1
# 5. How many b's are in idea? <-- a letter not in word (count should be zero)
def generate_records():
    for word in ALL_WORDS:
        for letter in sorted(set(word)):
            yield {"words": word, "letters": letter, "counts": word.count(letter)}

        # pick random letters not in the word
        num_letters_not_in_word_left = int(len(word) // 7 + 1)

        random.seed(hash(word))

        all_letters = list("abcdefghijklmnopqrstuvwxyz")

        random.shuffle(all_letters)
        for letter in all_letters:
            if letter not in word:
                yield {"words": word, "letters": letter, "counts": 0}
                num_letters_not_in_word_left -= 1
            if num_letters_not_in_word_left == 0:
                break


ds = Dataset.from_generator(generate_records)

# Show the first item
ds[0]
# Out:
# {'words': 'idea', 'letters': 'a', 'counts': 1}

# %%
# Add the entire prompt (system + user) and the answer to the dataset
# We'll use a prompt that spells out the word letter-by-letter
# No changes needed in this cell

import re
from datasets import load_dataset, Dataset

# Simple CoT prompt (zero-shot)
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
Counting the number of [letter_to_count]'s in the word [word]
1. [first letter] - [count of requested letter so far] so far
2. [second letter] - [count of requested letter so far] so far
...
</reasoning>
<answer>
[number]
</answer>
"""

ds = ds.map(
    lambda x: {  # type: ignore
        "prompt": [
            {"role": "system", "content": SYSTEM_PROMPT},
            {
                "role": "user",
                "content": 'How many of the letter "{}" are there in the word "{}"'.format(
                    x["letters"], x["words"]
                ),
            },
        ],
    }
)

ds[10]
# Out:
# {'words': 'rust',
#  'letters': 'r',
#  'counts': 1,
#  'prompt': [{'content': "\nRespond in the following format:\n<reasoning>\nCounting the number of [letter_to_count]'s in the word [word]\n1. [first letter] - [count of requested letter so far] so far\n2. [second letter] - [count of requested letter so far] so far\n...\n</reasoning>\n<answer>\n[number]\n</answer>\n",
#    'role': 'system'},
#   {'content': 'How many of the letter "r" are there in the word "rust"',
#    'role': 'user'}]}

# %%
# Let's see how well the model runs out-of-the-box
# No changes needed in this cell

text = tokenizer.apply_chat_template(
    ds[0]["prompt"], tokenize=False, add_generation_prompt=True
)

from vllm import SamplingParams

sampling_params = SamplingParams(
    temperature=0.8,
    top_p=0.95,
    max_tokens=1024,
)
output = (
    model.fast_generate(
        [text],
        sampling_params=sampling_params,
        lora_request=None,
    )[0]
    .outputs[0]
    .text
)

print(output)
# Out:
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 815.85it/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.73s/it, est. speed input: 60.74 toks/s, output: 37.60 toks/s]
# <reasoning>
# Counting the number of a's in the word idea
# 1. i - 0 so far
# 2. d - 1 so far
# 3. e - 2 so far
# 4. a - 3 so far
# </reasoning>
# <answer>
# 3
# </answer>

# %% [markdown]
# ## Create Reward Functions
#
# One goal of creating reward functions is to guide the model toward behaviors that help it reach its goal (counting the occurrences of a letter within a word) more easily. Since there is more than one way to carry out any step-by-step task (e.g. whether or not you use bullet points to separate your steps), there's a bit of judgement involved in choosing what behaviors to reward, i.e. how do we provide partial credit or "shape" our rewards?
#
# In this case we will encourage the model to (whether or not this structure is best):
# * use numbers for bullet points when spelling out the word
# * to spell the word correctly
# * to count the requested letter correctly
# * to use the requested reasoning format
# * to get the final answer correct.

# %% [markdown]
# ### Numbering reward function

# %%
# Let's work on a function that the numbering in the bullet points is correct
# When using GRPO, we lean on reward functions that are relatively easy to
# compute, thus removing the need to have a second large model just for
# evaluation.
# In this case, we'll use regular expressions quite a bit.
# TODO: Fill in the missing parts marked with **********


def extract_letter_numbering(response):
    """Extract the numbers at the beginning of the line

    Example:
    1. g - 1 so far
    2. o - 1 so far
    3. a - 2 so far
    4. a - 2 so far
    5. l - 2 so far
    returns [1, 2, 3, 4, 5]
    """
    import re

    # We use a regular expression to find lines of the form:
    # '\n[number]. [letter]'
    pattern = r"\n(\d+). [a-z]"

    # Use `re` to find all matches of the pattern in the response
    matches = re.findall(pattern,response, flags=re.IGNORECASE)
    if matches:
        return [int(m) for m in matches]
    return []


assert extract_letter_numbering(
    """
1. g - 1 so far
2. o - 1 so far
3. a - 2 so far
4. a - 2 so far
5. l - 2 so far
"""
) == [1, 2, 3, 4, 5]


def numbering_reward_func(completions, words, **kwargs) -> list[float]:
    """Provides a reward for getting the numbering at the beginning of the line correct

    1. g - 1 so far <-- Good in-order numbering
    2. o - 1 so far <-- Good in-order numbering
    3. a - 2 so far <-- Good in-order numbering
    3. l - 2 so far <-- Bad numbering, out-of-order, 3 should be 4
    1. l - 2 so far <-- Bad numbering, extra letter and out-of-order
    1. l - 2 so far <-- Bad numbering, extra letter and out-of-order

    """
    responses = [completion[0]["content"] for completion in completions]

    res = []
    for response, word in zip(responses, words):
        reward = 0

        for ix, spell_number in enumerate(extract_letter_numbering(response)):
            line_number = ix + 1

            # Get points for in-order numbering
            if spell_number == line_number:
                # TODO: Provide a reward for in-order numbering
                # (positive for good behavior, negative for bad)
                reward += 0.5
            # Otherwise lose points
            else:
                # TODO: Provide a reward for out-of-order numbering
                # (positive for good behavior, negative for bad)
                reward -= 0.5

            # Lose extra points for continuing beyond the length of the word
            if line_number > len(word):  # We use the index of the line
                # TODO: Provide a reward for continuing beyond the length of the word
                # (positive for good behavior, negative for bad)
                reward -= 1.0

        res.append(reward / len(word))
    return res


res = numbering_reward_func(
    completions=[
        [
            {  # Worse response
                "content": """<reasoning>
Here is a letter by letter spelling:
1. g - 1 so far <-- Good in-order numbering
2. o - 1 so far <-- Good in-order numbering
3. a - 2 so far <-- Good in-order numbering
3. l - 2 so far <-- Bad numbering, out-of-order, 3 should be 4
1. l - 2 so far <-- Bad numbering, extra letter and out-of-order
1. l - 2 so far <-- Bad numbering, extra letter and out-of-order
</reasoning>
<answer>2</answer>"""
            },
        ],
        [
            {  # Better response
                "content": """<reasoning>
Here is a letter by letter spelling:
1. g - 1 so far <-- Good in-order numbering
2. o - 1 so far <-- Good in-order numbering
3. a - 2 so far <-- Good in-order numbering
3. l - 2 so far <-- Bad numbering, out-of-order, 3 should be 4
</reasoning>
<answer>2</answer>"""
            },
        ],
    ],
    words=["goal", "goal"],
)
print(res)

assert res[1] > res[0], "The better response should have a higher reward"
# Out:
# [-0.5, 0.25]

# %% [markdown]
# ### Spelling reward function

# %%
# Reward correct spelling of the word
# TODO: Fill in the missing parts marked with **********


def extract_spelling(response):
    """Extract the spelling from the response

    Example:
    1. g - 1 so far
    2. o - 1 so far
    3. a - 2 so far
    3. l - 2 so far
    5. l - 2 so far
    Returns "goall"
    """
    import re

    pattern = r"\n\d+. ([a-z])"
    matches = re.findall(pattern, response, flags=re.IGNORECASE)
    if matches:
        return "".join([m for m in matches])
    return ""


extract_spelling(
    """Here is a letter by letter spelling:

1. g - 1 so far
2. o - 1 so far
3. a - 2 so far
3. l - 2 so far
5. l - 2 so far
"""
) == "goall"


def spelling_reward_func(completions, words, **kwargs) -> list[float]:
    """A spelling reward function."""
    from collections import Counter

    responses = [completion[0]["content"] for completion in completions]

    res = []

    for word, response in zip(words, responses):
        spelling=extract_spelling(response)
        reward = 0.0

        # Provide a reward for exactly correct spelling
        if spelling==word:
            reward += 2.0

        # Provide a reward for each letter of difference in length
        reward -= 0.5 * abs(len(spelling)-len(word))

        # Provide a reward for each letter that is not in the target word
        spelled_c = Counter(spelling)
        word_c = Counter(word)

        extras = sum(max(spelled_c[ch] - word_c.get(ch, 0), 0) for ch in spelled_c)
        reward -= 0.5 * extras


        # Provide a reward for each letter that is in the target word but not in the response
        missing = sum(max(word_c[ch] - spelled_c.get(ch, 0), 0) for ch in word_c)
        reward -= 1.0 * missing


        res.append(reward)
    return res


res = spelling_reward_func(
    completions=[
        [  # Worse response
            {
                "content": """<reasoning>
Here is a letter by letter spelling:
1. g - 1 so far
2. o - 1 so far
3. a - 2 so far
4. l - 2 so far
5. l - 2 so far
</reasoning>
<answer>2</answer>"""
            }
        ],
        [  # Better Response
            {
                "content": """<reasoning>
Here is a letter by letter spelling:
1. g - 1 so far
2. o - 1 so far
3. a - 2 so far
4. l - 2 so far
</reasoning>
<answer>2</answer>"""
            }
        ],
    ],
    words=["goal", "goal"],
)

print(res)

assert res[1] > res[0], "The better response should have a higher reward"
# Out:
# [-1.0, 2.0]

# %% [markdown]
# ### Counting reward function

# %%
# Let's reward the model for properly counting the occurrences of a letter in a word
# TODO: Fill in the missing parts marked with **********
# No changes needed in this cell, but feel free to experiment with variations on the prompt


def get_resp_letters_and_counts(response):
    """Extract the letters and counts from the response

    Example:
    1. g - 1 so far
    2. o - 1 so far
    3. a - 2 so far
    4. a - 2 so far
    5. l - 2 so far
    returns [('g', 1), ('o', 1), ('a', 2), ('a', 2), ('l', 2)]
    """
    import re

    pattern = r"\n(\d+)\. ([a-z])\D*(\d+)"

    # Find strings matching e.g. "2. a - 2 so far"
    matches = re.findall(pattern, response, flags=re.IGNORECASE)

    if not matches:
        return []

    return [
        (matched_letter, matched_count_so_far)
        for _, matched_letter, matched_count_so_far in matches
    ]


assert get_resp_letters_and_counts(
    """
1. g - 1 so far
2. o - 1 so far
3. a - 2 so far
4. a - 2 so far
5. l - 2 so far
"""
) == [("g", "1"), ("o", "1"), ("a", "2"), ("a", "2"), ("l", "2")]


def counting_reward_func(completions, letters, **kwargs) -> list[float]:
    responses = [completion[0]["content"] for completion in completions]

    res = []

    # Iterate over each of the letter-response pairs
    for letter, response in zip(letters, responses):
        reward = 0.0

        letters_and_counts = get_resp_letters_and_counts(response)

        # If there are no matches, provide a negative reward
        if not letters_and_counts:
            res.append(-1.0)
            continue

        # Start counting the matching letters
        actual_count = 0
        for resp_letter, resp_count in letters_and_counts:
            # If there's a match, count the letter
            if letter == resp_letter:
                actual_count += 1
            try:
                resp_count_int = int(resp_count)
            except ValueError:
                # Treat unparsable count as incorrect for this step
                resp_count_int = None


            # If the count is accurate, add a reward, else subtract a reward
            if resp_count_int is not None and actual_count == resp_count_int:
                reward += +1.0
            else:
                reward -= 1.0

        # Return the reward normalized by the length of the matches
        denom = max(1, len(letters_and_counts))
        res.append(reward / denom)
    return res


res = counting_reward_func(
    completions=[
        [  # Worse response
            {
                "content": """<reasoning>\nHere is a letter by letter spelling:

1. g - 0 so far
2. o - 0 so far
3. a - 1 so far
4. a - 2 so far
5. l - 0 so far

\n</reasoning>\n<answer>\nThis is my answer.\n</answer>"""
            }
        ],
        [  # Better response
            {
                "content": """<reasoning>\nHere is a letter by letter spelling:

1. g - 1 so far
2. o - 1 so far
3. a - 1 so far
4. a - 1 so far
5. l - 1 so far

\n</reasoning>\n<answer>\nThis is my answer.\n</answer>"""
            }
        ],
    ],
    letters=["g", "g"],
)

print(res)

assert res[1] > res[0], "The better response should have a higher reward"
# Out:
# [-0.6, 1.0]

# %% [markdown]
# ### Formatting reward functions

# %%
# Reward the model for providing the response in a specific format
# TODO: Fill in the missing parts marked with **********


def extract_xml_answer(text: str) -> str:
    """Extracts the string between <answer> and </answer> tags."""
    import re

    pattern = r"<answer>(.*?)</answer>"
    match = re.search(pattern, text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return ""


assert (
    extract_xml_answer("""
<reasoning>
This is my reasoning.
</reasoning>
<answer>SUPERCALIFRAGILISTICEXPIALIDOCIOUS</answer>
""")
    == "SUPERCALIFRAGILISTICEXPIALIDOCIOUS"
)


def format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"\s*<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"

    res = []

    for completion in completions:
        reward = 0.0

        # Extract the response content
        response = completion[0]["content"]

        # Check if the response matches the pattern
        match = re.match(pattern, response, flags=re.MULTILINE | re.DOTALL)
        print(match)
        # If it matches, return 0.5, otherwise return 0.0
        if match==response:
            reward += 0.5
        # Extract the answer from the response
        extracted_answer = extract_xml_answer(response)
        print("*****Extract**",extracted_answer)
        # If the answer is an integer, add 0.5 to the reward
        if extracted_answer != "" and re.fullmatch(r"[+-]?\d+", extracted_answer):
            reward +=0.5

        res.append(reward)
    return res


res = format_reward_func(
    completions=[
        [{"content": "This is my answer"}],
        [
            {
                "content": "<reasoning>\nThis is my reasoning.\n</reasoning>\n<answer>\n3\n</answer>"
            }
        ],
    ]
)

print(res)

assert res[1] > res[0], "The better response should have a higher reward"
# Out:
# None
# *****Extract**
# <re.Match object; span=(0, 67), match='<reasoning>\nThis is my reasoning.\n</reasoning>\>
# *****Extract** 3
# [0.0, 0.5]

# %% [markdown]
# ### Task correctness reward function

# %%
# Reward the model for providing the correct answer
# TODO: Fill in the missing parts marked with **********


def correct_answer_reward_func(prompts, completions, counts, **kwargs) -> list[float]:
    """Reward the final answer if it is correct."""
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [extract_xml_answer(r) for r in responses]

    # Print a nice summary of the first prompt, answer, and response to see while training
    print(f"""
{"-" * 20}
Question: {prompts[0][-1]["content"]}
Answer: {counts[0]}
Response: {responses[0]}
Extracted: {extracted_responses[0]}
Correct: {str(extracted_responses[0]) == str(counts[0])}!
    """)

    def _norm(x):
        return "" if x is None else str(x).strip()

    res = [
        # Provide reward for exactly correct answer
       (1.0 if _norm(r) == _norm(a) else 0.0)
        for r, a in zip(extracted_responses, counts)
    ]
    return res


res = correct_answer_reward_func(
    prompts=[
        [{"content": """How many..."""}],
        [{"content": """How many..."""}],
    ],
    completions=[
        [{"content": """<reasoning>.../reasoning>\n<answer>\n3\n</answer>"""}],
        [{"content": """<reasoning>.../reasoning>\n<answer>\n3\n</answer>"""}],
    ],
    letters=["g", "g"],
    counts=[0, 3],
)

print(res)

assert res[1] > res[0], "The better response should have a higher reward"
# Out:
# --------------------
# Question: How many...
# Answer: 0
# Response: <reasoning>.../reasoning>
# <answer>
# 3
# </answer>
# Extracted: 3
# Correct: False!
#
# [0.0, 1.0]

# %% [markdown]
# ### List the reward functions

# %%
# List out the reward functions we will use
# No changes needed in this cell

REWARD_FUNCS = [
    numbering_reward_func,
    spelling_reward_func,
    counting_reward_func,
    format_reward_func,
    correct_answer_reward_func,
]

# %% [markdown]
# ## Train the model
#
# Now set up GRPO Trainer and configurations!
#
# As you run the trainer, the goal is to see the various `reward` columns increase.
#
# After 50 steps or more, you may notice some of the reward standard deviations begin to decrease, meaning that the different predictions are starting to converge on solutions that give similar rewards. If your model has learned the task, then you'll see the `correct_answer_reward_function` increase to its highest value (check the function to see what that is).
#
# Here is an example, which successfully converged on a higher reward. Note, the values you see here will probably be different from yours, especially if your reward amounts are different.
#
# | Step | Training Loss | reward   | reward_std | ... | kl      | rewards / correct_answer_reward_function / mean | rewards / correct_answer_reward_function / std |
# |------|---------------|----------|------------|-----|---------|------------------------------------------|-----------------------------------------|
# | 1    | 0.000000      | 7.961805 | 2.368493   | ... | 0.020369| 0.875000                                 | 1.024695                                |
# | 2    | 0.000000      | 7.937500 | 1.352467   | ... | 0.016483| 0.875000                                 | 1.024695                                |
# | 3    | 0.000000      | 1.894792 | 6.462189   | ... | 0.013677| 0.375000                                 | 0.806226                                |
# | ...  | ...           | ...      | ...        | ... | ...     | ...                                      | ...                                     |
# | 398  | 0.000100      | 13.000000| 0.000000   | ... | 0.088529| 2.000000                                 | 0.000000                                |
# | 399  | 0.000100      | 13.000000| 0.000000   | ... | 0.088617| 2.000000                                 | 0.000000                                |
# | 400  | 0.000100      | 13.000000| 0.000000   | ... | 0.096202| 2.000000                                 | 0.000000                                |

# %%
# Fill in the GRPO Parameters we'll use throughout this project
# TODO: Fill in the missing parts marked with **********

# Read about the GRPO params here https://huggingface.co/docs/trl/main/en/grpo_trainer
COMMON_GRPO_TRAINING_PARAMS = dict(
    # Set appropriate values for `learning_rate` and `beta`
    # See: https://docs.unsloth.ai/get-started/fine-tuning-llms-guide/lora-hyperparameters-guide
    # See: https://huggingface.co/docs/trl/main/en/grpo_trainer
    learning_rate=5e-6,
    beta=0.001,
    # Set the batch size appropriately for your hardware. For GRPO there are a number of parameters to set.
    # If you are not sure about your GPU, assume you have a T4. See the memory specs here:
    # https://www.nvidia.com/content/dam/en-zz/Solutions/Data-Center/tesla-product-literature/T4%20Product%20Brief.pdf
    per_device_train_batch_size=16,  # per_device_train_batch_size / num_generations determines the number of simultaneous prompts to consider.
    # Note: Set per_device_train_batch_size to at most 16 on the Vocareum T4 for best stability
    num_generations=4,  # Determines the number of completions/generations to compute for each single prompt
    gradient_accumulation_steps=1,  # This parameter allow us to consider multiple steps in a single optimization step
    adam_beta1=0.9,
    adam_beta2=0.99,
    weight_decay=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    optim="adamw_8bit",
    logging_steps=1,
    max_prompt_length=256,
    max_completion_length=200,
    num_train_epochs=1,  # Set to 1 for a full training run
    save_steps=250,
    max_grad_norm=0.1,
    report_to="none",  # Setting this value lets us use Weights and Biases
    output_dir="outputs",
    use_vllm=True,  # vll speeds up inference! See https://github.com/vllm-project/vllm
)

# %% [markdown]
# ### Quick train
#
# Let's train the model for just 5 steps (`max_steps=5`). As it runs we can double check we've set up our prompts correctly before running for a longer amount of time.

# %%
# Train for just a few steps for a few minutes
# This will allow us to observe the results and make any changes to our reward functions
# before starting a longer run. Note, you won't see much change in the average.
# reward values
# No changes are needed here

from trl import GRPOConfig, GRPOTrainer

# Short train to check on reward functions
training_args = GRPOConfig(
    **COMMON_GRPO_TRAINING_PARAMS,
    # We'll just run for a modest 5 steps to make sure everything works and to
    # estimate the amount of time it will take to run the full training.
    max_steps=5,
)
trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    reward_funcs=REWARD_FUNCS,
    args=training_args,
    train_dataset=ds,
)
trainer_res = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 401 | Num Epochs = 1 | Total steps = 5
# O^O/ \_/ \    Batch size per device = 16 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (16 x 1 x 1) = 16
#  "-____-"     Trainable parameters = 7,372,800 of 3,093,311,488 (0.24% trained)
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 306), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "x"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 187), match='<reasoning>\nCounting the number of "x" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 169), match='<reasoning>\nCounting the number of x\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 212), match='<reasoning>\nCounting the number of x\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 237), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "w" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 248), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 185), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "g" are there in the word "glisten"
# Answer: 1
# Response: <reasoning>
# Counting the number of "g"s in the word "glisten"
# 1. g - 1 so far
# 2. l - 1 so far
# 3. i - 1 so far
# 4. s - 1 so far
# 5. t - 1 so far
# 6. n - 1 so far
# 7. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:57, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / numbering_reward_func / mean</th>
#       <th>rewards / numbering_reward_func / std</th>
#       <th>rewards / spelling_reward_func / mean</th>
#       <th>rewards / spelling_reward_func / std</th>
#       <th>rewards / counting_reward_func / mean</th>
#       <th>rewards / counting_reward_func / std</th>
#       <th>rewards / format_reward_func / mean</th>
#       <th>rewards / format_reward_func / std</th>
#       <th>rewards / correct_answer_reward_func / mean</th>
#       <th>rewards / correct_answer_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000100</td>
#       <td>1.945833</td>
#       <td>1.703636</td>
#       <td>86.625000</td>
#       <td>68.000000</td>
#       <td>122.000000</td>
#       <td>0.000000</td>
#       <td>86.625000</td>
#       <td>68.000000</td>
#       <td>122.000000</td>
#       <td>0.056264</td>
#       <td>0.448661</td>
#       <td>0.076564</td>
#       <td>0.312500</td>
#       <td>1.447699</td>
#       <td>-0.065327</td>
#       <td>0.758027</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>0.447214</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.940538</td>
#       <td>0.950104</td>
#       <td>83.750000</td>
#       <td>66.000000</td>
#       <td>113.000000</td>
#       <td>0.000000</td>
#       <td>83.750000</td>
#       <td>66.000000</td>
#       <td>113.000000</td>
#       <td>0.055673</td>
#       <td>0.449219</td>
#       <td>0.056912</td>
#       <td>-0.718750</td>
#       <td>2.421905</td>
#       <td>0.210069</td>
#       <td>0.765829</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.516398</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>1.380208</td>
#       <td>1.705514</td>
#       <td>91.812500</td>
#       <td>67.000000</td>
#       <td>137.000000</td>
#       <td>0.000000</td>
#       <td>91.812500</td>
#       <td>67.000000</td>
#       <td>137.000000</td>
#       <td>0.032213</td>
#       <td>0.465774</td>
#       <td>0.050484</td>
#       <td>-0.781250</td>
#       <td>1.570231</td>
#       <td>0.570684</td>
#       <td>0.649968</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>2.098214</td>
#       <td>0.678127</td>
#       <td>89.937500</td>
#       <td>85.000000</td>
#       <td>103.000000</td>
#       <td>0.000000</td>
#       <td>89.937500</td>
#       <td>85.000000</td>
#       <td>103.000000</td>
#       <td>0.036741</td>
#       <td>0.447917</td>
#       <td>0.073755</td>
#       <td>0.343750</td>
#       <td>2.047102</td>
#       <td>0.306548</td>
#       <td>0.794914</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.516398</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>2.273512</td>
#       <td>1.306727</td>
#       <td>84.625000</td>
#       <td>67.000000</td>
#       <td>111.000000</td>
#       <td>0.000000</td>
#       <td>84.625000</td>
#       <td>67.000000</td>
#       <td>111.000000</td>
#       <td>0.037225</td>
#       <td>0.493750</td>
#       <td>0.025000</td>
#       <td>0.281250</td>
#       <td>2.016340</td>
#       <td>0.373512</td>
#       <td>0.620067</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#   </tbody>
# </table><p>
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 4
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of e\'s in the w>
# *****Extract** 4
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 153), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 197), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "e" are there in the word "sapphire"
# Answer: 1
# Response: <reasoning>
# Counting the number of "e" in the word "sapphire"
# 1. s - 0 so far
# 2. a - 1 so far
# 3. p - 1 so far
# 4. h - 1 so far
# 5. a - 2 so far
# 6. p - 2 so far
# 7. y - 2 so far
# 8. e - 3 so far
# </reasoning>
# <answer>
# 3
# </answer>
# Extracted: 3
# Correct: False!
#
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of w\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of w\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 241), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of w\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 358), match='<reasoning>\nCounting the number of h\'s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 221), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 229), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "w" are there in the word "absolve"
# Answer: 0
# Response: <reasoning>
# Counting the number of w's in the word "absolve"
# 1. a - 0 so far
# 2. b - 0 so far
# 3. s - 0 so far
# 4. w - 0 so far
# 5. v - 0 so far
# 6. e - 0 so far
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: True!
#
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 4
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 203), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 191), match='<reasoning>\nCounting the number of "e"\'s in the>
# *****Extract** 5
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "g" are there in the word "mirage"
# Answer: 1
# Response: <reasoning>
# Counting the number of "g" in the word "mirage"
# 1. m - 0 so far
# 2. i - 0 so far
# 3. r - 0 so far
# 4. a - 0 so far
# 5. g - 1 so far
# 6. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 230), match='<reasoning>\nCounting the number of r\'s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 241), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 260), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "r" are there in the word "crave"
# Answer: 1
# Response: <reasoning>
# Counting the number of "r" in the word "crave"
# 1. c - 0 so far
# 2. r - 1 so far
# 3. a - 1 so far
# 4. v - 1 so far
# 5. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!

# %%
# Show the total (sum) of the rewards as well as the correct_answer_reward_func (means with in the batch)
# No changes needed in this cell

import pandas as pd
import matplotlib.pyplot as plt

# If you want to graph other columns, check these out
print(f"available columns: {trainer.state.log_history[0].keys()}")

log_df = pd.DataFrame(trainer.state.log_history)
log_df["reward"].plot()
log_df["rewards/correct_answer_reward_func/mean"].plot()

# Show the legend
plt.legend(["reward", "rewards/correct_answer_reward_func/mean"])
plt.show()
# Out:
# available columns: dict_keys(['loss', 'grad_norm', 'learning_rate', 'num_tokens', 'completions/mean_length', 'completions/min_length', 'completions/max_length', 'completions/clipped_ratio', 'completions/mean_terminated_length', 'completions/min_terminated_length', 'completions/max_terminated_length', 'rewards/numbering_reward_func/mean', 'rewards/numbering_reward_func/std', 'rewards/spelling_reward_func/mean', 'rewards/spelling_reward_func/std', 'rewards/counting_reward_func/mean', 'rewards/counting_reward_func/std', 'rewards/format_reward_func/mean', 'rewards/format_reward_func/std', 'rewards/correct_answer_reward_func/mean', 'rewards/correct_answer_reward_func/std', 'reward', 'reward_std', 'frac_reward_zero_std', 'completion_length', 'kl', 'epoch', 'step'])

# %% [markdown]
# ### Slower train (1+ hour)
#
# If everything looks good, let's go for a longer training session!

# %%
# Now let's train for real! Let's do a longer training that will take an hour or more
# Note: If this run is successful, you can consider doing a longer train
# to see what happens, but that's beyond the scope of this project.
# TODO: Fill out the areas where you find **********

# Full training
training_args = GRPOConfig(
    **COMMON_GRPO_TRAINING_PARAMS,
    # Configure the maximum number of steps to take about 30mins of time for
    # a medium-sized experiment. (See how long the previous example took and
    # scale up appropriately using your best guess.)
    max_steps=100,  # ~60min
)
trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    reward_funcs=REWARD_FUNCS,
    args=training_args,
    train_dataset=ds,
)
trainer_res = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 401 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 16 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (16 x 1 x 1) = 16
#  "-____-"     Trainable parameters = 7,372,800 of 3,093,311,488 (0.24% trained)
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 290), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "x"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 187), match='<reasoning>\nCounting the number of "x" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 169), match='<reasoning>\nCounting the number of x\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 212), match='<reasoning>\nCounting the number of x\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "w" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 213), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 185), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "g" are there in the word "glisten"
# Answer: 1
# Response: <reasoning>
# Counting the number of "g"s in the word "glisten"
# 1. g - 1 so far
# 2. l - 1 so far
# 3. i - 1 so far
# 4. s - 1 so far
# 5. t - 1 so far
# 6. n - 1 so far
# 7. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 23:06, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / numbering_reward_func / mean</th>
#       <th>rewards / numbering_reward_func / std</th>
#       <th>rewards / spelling_reward_func / mean</th>
#       <th>rewards / spelling_reward_func / std</th>
#       <th>rewards / counting_reward_func / mean</th>
#       <th>rewards / counting_reward_func / std</th>
#       <th>rewards / format_reward_func / mean</th>
#       <th>rewards / format_reward_func / std</th>
#       <th>rewards / correct_answer_reward_func / mean</th>
#       <th>rewards / correct_answer_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000100</td>
#       <td>2.411458</td>
#       <td>1.546455</td>
#       <td>85.187500</td>
#       <td>68.000000</td>
#       <td>113.000000</td>
#       <td>0.000000</td>
#       <td>85.187500</td>
#       <td>68.000000</td>
#       <td>113.000000</td>
#       <td>0.056133</td>
#       <td>0.464286</td>
#       <td>0.072316</td>
#       <td>0.687500</td>
#       <td>1.447699</td>
#       <td>-0.052827</td>
#       <td>0.749342</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.812500</td>
#       <td>0.403113</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>1.706944</td>
#       <td>1.751398</td>
#       <td>82.625000</td>
#       <td>67.000000</td>
#       <td>113.000000</td>
#       <td>0.000000</td>
#       <td>82.625000</td>
#       <td>67.000000</td>
#       <td>113.000000</td>
#       <td>0.049999</td>
#       <td>0.462500</td>
#       <td>0.053033</td>
#       <td>-0.343750</td>
#       <td>2.527969</td>
#       <td>0.400694</td>
#       <td>0.735320</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.687500</td>
#       <td>0.478714</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>2.331845</td>
#       <td>0.870922</td>
#       <td>89.000000</td>
#       <td>67.000000</td>
#       <td>112.000000</td>
#       <td>0.000000</td>
#       <td>89.000000</td>
#       <td>67.000000</td>
#       <td>112.000000</td>
#       <td>0.031263</td>
#       <td>0.447917</td>
#       <td>0.125000</td>
#       <td>-0.031250</td>
#       <td>1.443015</td>
#       <td>0.790179</td>
#       <td>0.502693</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>1.740774</td>
#       <td>0.613966</td>
#       <td>89.937500</td>
#       <td>74.000000</td>
#       <td>107.000000</td>
#       <td>0.000000</td>
#       <td>89.937500</td>
#       <td>74.000000</td>
#       <td>107.000000</td>
#       <td>0.037611</td>
#       <td>0.447917</td>
#       <td>0.067185</td>
#       <td>0.093750</td>
#       <td>2.353853</td>
#       <td>0.261607</td>
#       <td>0.763650</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.437500</td>
#       <td>0.512348</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>1.551042</td>
#       <td>1.858760</td>
#       <td>83.312500</td>
#       <td>58.000000</td>
#       <td>106.000000</td>
#       <td>0.000000</td>
#       <td>83.312500</td>
#       <td>58.000000</td>
#       <td>106.000000</td>
#       <td>0.037088</td>
#       <td>0.436458</td>
#       <td>0.130237</td>
#       <td>-0.375000</td>
#       <td>2.117388</td>
#       <td>0.364583</td>
#       <td>0.630464</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>3.113616</td>
#       <td>1.021518</td>
#       <td>85.250000</td>
#       <td>67.000000</td>
#       <td>113.000000</td>
#       <td>0.000000</td>
#       <td>85.250000</td>
#       <td>67.000000</td>
#       <td>113.000000</td>
#       <td>0.036228</td>
#       <td>0.426116</td>
#       <td>0.087333</td>
#       <td>0.218750</td>
#       <td>1.888286</td>
#       <td>0.968750</td>
#       <td>0.085391</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>1.444345</td>
#       <td>1.758992</td>
#       <td>79.250000</td>
#       <td>67.000000</td>
#       <td>95.000000</td>
#       <td>0.000000</td>
#       <td>79.250000</td>
#       <td>67.000000</td>
#       <td>95.000000</td>
#       <td>0.033873</td>
#       <td>0.437500</td>
#       <td>0.048795</td>
#       <td>-0.781250</td>
#       <td>1.879439</td>
#       <td>0.663095</td>
#       <td>0.585931</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.890476</td>
#       <td>1.321687</td>
#       <td>95.687500</td>
#       <td>62.000000</td>
#       <td>123.000000</td>
#       <td>0.000000</td>
#       <td>95.687500</td>
#       <td>62.000000</td>
#       <td>123.000000</td>
#       <td>0.031198</td>
#       <td>0.426190</td>
#       <td>0.072463</td>
#       <td>-1.250000</td>
#       <td>1.693123</td>
#       <td>0.651786</td>
#       <td>0.578621</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.562500</td>
#       <td>0.512348</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>1.218824</td>
#       <td>1.903514</td>
#       <td>94.875000</td>
#       <td>67.000000</td>
#       <td>134.000000</td>
#       <td>0.000000</td>
#       <td>94.875000</td>
#       <td>67.000000</td>
#       <td>134.000000</td>
#       <td>0.038182</td>
#       <td>0.446801</td>
#       <td>0.075150</td>
#       <td>-0.718750</td>
#       <td>1.879439</td>
#       <td>0.553274</td>
#       <td>0.624528</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.437500</td>
#       <td>0.512348</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>2.453125</td>
#       <td>0.681230</td>
#       <td>84.062500</td>
#       <td>76.000000</td>
#       <td>113.000000</td>
#       <td>0.000000</td>
#       <td>84.062500</td>
#       <td>76.000000</td>
#       <td>113.000000</td>
#       <td>0.039174</td>
#       <td>0.412946</td>
#       <td>0.088659</td>
#       <td>0.031250</td>
#       <td>1.848141</td>
#       <td>0.758929</td>
#       <td>0.449819</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>0.447214</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.580258</td>
#       <td>0.829925</td>
#       <td>88.375000</td>
#       <td>54.000000</td>
#       <td>122.000000</td>
#       <td>0.000000</td>
#       <td>88.375000</td>
#       <td>54.000000</td>
#       <td>122.000000</td>
#       <td>0.034613</td>
#       <td>0.354911</td>
#       <td>0.058465</td>
#       <td>-2.250000</td>
#       <td>1.154701</td>
#       <td>0.377331</td>
#       <td>0.651388</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.437500</td>
#       <td>0.512348</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>1.000980</td>
#       <td>0.907113</td>
#       <td>100.250000</td>
#       <td>78.000000</td>
#       <td>179.000000</td>
#       <td>0.000000</td>
#       <td>100.250000</td>
#       <td>78.000000</td>
#       <td>179.000000</td>
#       <td>0.045678</td>
#       <td>0.438281</td>
#       <td>0.062495</td>
#       <td>-1.125000</td>
#       <td>1.310216</td>
#       <td>0.562698</td>
#       <td>0.556942</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.884003</td>
#       <td>0.961769</td>
#       <td>84.500000</td>
#       <td>68.000000</td>
#       <td>
# <re.Match object; span=(0, 224), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 5
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 4
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "s"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "s"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "s"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 200), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "e" are there in the word "sapphire"
# Answer: 1
# Response: <reasoning>
# Counting the number of "e"s in the word "sapphire"
# 1. s - 0 so far
# 2. a - 1 so far
# 3. p - 1 so far
# 4. a - 2 so far
# 5. r - 2 so far
# 6. p - 3 so far
# 7. h - 3 so far
# 8. y - 3 so far
# </reasoning>
# <answer>
# 3
# </answer>
# Extracted: 3
# Correct: False!
#
# <re.Match object; span=(0, 256), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of w\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 225), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "w" are there in the word "absolve"
# Answer: 0
# Response: <reasoning>
# Counting the number of "w"s in the word "absolve"
# 1. a - 0 so far
# 2. b - 0 so far
# 3. s - 0 so far
# 4. l - 0 so far
# 5. o - 0 so far
# 6. v - 0 so far
# 7. e - 0 so far
# Therefore, the number of "w"s in "absolve" is 0.
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: True!
#
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 234), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 221), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 171), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 4
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of e\'s in the w>
# *****Extract** 3
#
# --------------------
# Question: How many of the letter "g" are there in the word "mirage"
# Answer: 1
# Response: <reasoning>
# Counting the number of "g"s in the word "mirage"
# 1. m - 0 so far
# 2. i - 0 so far
# 3. r - 0 so far
# 4. a - 0 so far
# 5. g - 1 so far
# 6. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 235), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 170), match="<reasoning>\nCounting the number of r's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 235), match="<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 2
# <re.Match object; span=(0, 139), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 139), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "r" are there in the word "crave"
# Answer: 1
# Response: <reasoning>
# Counting the number of "r"s in the word "crave"
# 1. c - 0 so far
# 2. r - 1 so far
# 3. r - 1 (current count, 1) + 1 (first occurrence) = 2 so far
# 4. a - 2 so far
# 5. v - 2 so far
# 6. e - 2 so far
# </reasoning>
# <answer>
# 2
# </answer>
# Extracted: 2
# Correct: False!
#
# <re.Match object; span=(0, 251), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 233), match='<reasoning>\nCounting the number of letter "w" in>
# *****Extract** 0
# <re.Match object; span=(0, 229), match='<reasoning>\nCounting the number of "w" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "w" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 247), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 204), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 169), match="<reasoning>\nCounting the number of t's in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "w" are there in the word "frescos"
# Answer: 0
# Response: <reasoning>
# Counting the number of "w"s in the word "frescos"
# 1. f - 0 so far
# 2. r - 0 so far
# 3. e - 0 so far
# 4. s - 0 so far
# 5. c - 0 so far
# 6. o - 0 so far
# 7. s - 0 so far
# So, there are 0 "w"s in the word "frescos".
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: True!
#
# <re.Match object; span=(0, 191), match='<reasoning>\nCounting the number of "v"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of v\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "v" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "v" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 209), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "v" are there in the word "absolve"
# Answer: 1
# Response: <reasoning>
# Counting the number of "v"s in the word "absolve"
# 1. a - 0 so far
# 2. b - 0 so far
# 3. s - 0 so far
# 4. o - 0 so far
# 5. v - 1 so far
# 6. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 256), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 191), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 216), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 125), match='<reasoning>\n1. c - 0 so far\n2. r - 0 so far\n3.>
# *****Extract** 0
# <re.Match object; span=(0, 218), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 187), match="<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 0
# <re.Match object; span=(0, 252), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 5
#
# --------------------
# Question: How many of the letter "i" are there in the word "eclipse"
# Answer: 1
# Response: <reasoning>
# Counting the number of "i" in the word "eclipse"
# 1. e - 0 so far
# 2. c - 0 so far
# 3. l - 0 so far
# 4. e - 0 so far
# 5. p - 0 so far
# 6. l - 0 so far
# 7. c - 0 so far
# 8. e - 0 so far
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: False!
#
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 196), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "e"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 334), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 237), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 202), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 341), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 4
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 187), match="<reasoning>\nCounting the number of a's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "e" are there in the word "echo"
# Answer: 1
# Response: <reasoning>
# Counting the number of "e" in the word "echo"
# 1. e - 1 so far
# 2. c - 0 so far
# 3. h - 0 so far
# 4. o - 0 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 4
# <re.Match object; span=(0, 187), match='<reasoning>\nCounting the number of "d"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 192), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "g" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 211), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "g"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "d" are there in the word "void"
# Answer: 1
# Response: <reasoning>
# Counting the number of "d"s in the word "void"
# 1. v - 0 so far
# 2. o - 1 so far
# 3. i - 2 so far
# 4. v - 3 so far
# 5. d - 4 so far
# </reasoning>
# <answer>
# 4
# </answer>
# Extracted: 4
# Correct: False!
#
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of o\'s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 136), match="<reasoning>\nCounting the number of n's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 183), match="<reasoning>\nCounting the number of n's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 138), match='<reasoning>\nCounting the number of "n" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "n" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 204), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 213), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "u"s in the w>
# *****Extract** 6
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 255), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 3
#
# --------------------
# Question: How many of the letter "o" are there in the word "ivory"
# Answer: 1
# Response: <reasoning>
# Counting the number of "o"s in the word "ivory"
# 1. i - 0 so far
# 2. v - 0 so far
# 3. i - 1 so far
# 4. o - 1 so far
# 5. r - 1 so far
# 6. y - 1 so far
# </reasoning>
# <answer>
# 2
# </answer>
# Extracted: 2
# Correct: False!
#
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 506), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 286), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 6
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of r\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 204), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of b\'s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "p" are there in the word "aperture"
# Answer: 1
# Response: <reasoning>
# Counting the number of "p" in the word "aperture"
# 1. a - 0 so far
# 2. p - 1 so far
# 3. e - 1 so far
# 4. t - 1 so far
# 5. r - 1 so far
# 6. u - 1 so far
# 7. e - 2 so far
# 8. a - 2 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 171), match="<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "m" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "m"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "m" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 353), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 191), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of b\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 237), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 157), match='<reasoning>\nCounting the number of "u"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "u"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 187), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 187), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "m" are there in the word "fume"
# Answer: 1
# Response: <reasoning>
# Counting the number of [letter_to_count]'s in the word [word]
# 1. f - 0 so far
# 2. u - 1 so far
# 3. m - 1 so far
# 4. e - 2 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "c"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 160), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 125), match='<reasoning>\n1. c - 1 so far\n2. r - 0 so far\n3.>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of d\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of l\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 169), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 208), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 203), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "c" are there in the word "crave"
# Answer: 1
# Response: <reasoning>
# Counting the number of "c"'s in the word "crave"
# 1. c - 1 so far
# 2. r - 0 so far
# 3. r - 1 so far
# 4. a - 0 so far
# 5. v - 0 so far
# 6. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 444), match='<reasoning>\nCounting the number of "f"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 170), match='<reasoning>\nCounting the number of "f"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 249), match='<reasoning>\nCounting the number of f\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 252), match="<reasoning>\nCounting the number of f's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "o" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 171), match='<reasoning>\nCounting the number of "v" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "v"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "v"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "v" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 212), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 228), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "f" are there in the word "frescos"
# Answer: 1
# Response: <reasoning>
# Counting the number of "f"s in the word "frescos"
# 1. f - 1 so far
# 2. r - 0 (no previous f's, just starts counting)
# 3. e - 0 (no previous f's, just continues counting)
# 4. s - 0 (no previous f's, just continues counting)
# 5. c - 0 (no previous f's, just continues counting)
# 6. o - 0 (no previous f's, just continues counting)
# 7. s - 0 (no previous f's, just continues counting)
# So far, there is 1 "f".
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "b"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "b" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "b" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 218), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 296), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "b" are there in the word "banner"
# Answer: 1
# Response: <reasoning>
# Counting the number of "b"s in the word "banner"
# 1. b - 1 so far
# 2. a - 1 so far
# 3. n - 1 so far
# 4. a - 2 so far
# 5. r - 2 so far
# 6. b - 3 so far
# </reasoning>
# <answer>
# 3
# </answer>
# Extracted: 3
# Correct: False!
#
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "m"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "m"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 323), match='<reasoning>\nCounting the number of "m"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "m" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 204), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 220), match="<reasoning>\nCounting the number of j's in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "j"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "j"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "j" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 191), match='<reasoning>\nCounting the number of "d"\'s in the>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "m" are there in the word "capture"
# Answer: 0
# Response: <reasoning>
# Counting the number of "m"s in the word "capture"
# 1. c - 0 so far
# 2. a - 1 so far
# 3. p - 2 so far
# 4. c - 3 so far
# 5. a - 4 so far
# 6. t - 4 so far
# 7. e - 5 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: False!
#
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 242), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 187), match="<reasoning>\nCounting the number of e's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 185), match="<reasoning>\nCounting the number of e's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 280), match='<reasoning>\nCounting the number of e\'s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 210), match="<reasoning>\nCounting the number of e's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "p" are there in the word "sphinx"
# Answer: 1
# Response: <reasoning>
# Counting the number of "p" in the word "sphinx"
# 1. s - 0 so far
# 2. p - 1 so far
# 3. h - 1 so far
# 4. n - 1 so far
# 5. f - 1 so far
# 6. k - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 271), match="<reasoning>\nCounting the number of k's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 122), match="<reasoning>\nCounting the number of k's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 218), match='<reasoning>\nCounting the number of "k"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "k"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 260), match='<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 0
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 243), match='<reasoning>\nCounting the number of "d" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "d"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 203), match="<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 0
# <re.Match object; span=(0, 125), match='<reasoning>\n1. i - 1 so far\n2. v - 1 so far\n3.>
# *****Extract** 1
# <re.Match object; span=(0, 219), match='<reasoning>\nCounting the number of "v"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 177), match='<reasoning>\nCounting the number of "v"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "v" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "k" are there in the word "knack"
# Answer: 2
# Response: <reasoning>
# Counting the number of k's in the word knack
# 1. k - 1 so far
# 2. n - 0 (starting count) so far
# 3. a - 0 (starting count) so far
# 4. k - 1 (previous count) so far
# ...
# *****Extract** 2
# <re.Match object; span=(0, 305), match='<reasoning>\nCounting the number of "c" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 224), match='<reasoning>\nCounting the number of "c"\'s in the>
# *****Extract** 2
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "c" in the wo>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "i" are there in the word "fusion"
# Answer: 1
# Response: <reasoning>
# Counting the number of "i"s in the word "fusion"
# 1. f - 0 so far
# 2. u - 0 so far
# 3. s - 0 so far
# 4. i - 0 so far
# 5. o - 0 so far
# 6. n - 0 so far
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: False!
#
# <re.Match object; span=(0, 204), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 170), match="<reasoning>\nCounting the number of e's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 187), match='<reasoning>\nCounting the number of "i"\'s in the>
# *****Extract** 0
# <re.Match object; span=(0, 228), match='<reasoning>\nTo count the number of letter "i" in>
# *****Extract** 0
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "q" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "q"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 267), match='<reasoning>\nCounting the number of "q"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "q"s in the w>
# *****Extract** 0
#
# --------------------
# Question: How many of the letter "s" are there in the word "whistle"
# Answer: 1
# Response: <reasoning>
# Counting the number of s's in the word whistle
# 1. w - 0 so far
# 2. h - 0 so far
# 3. i - 0 so far
# 4. s - 1 so far
# 5. t - 1 so far
# 6. l - 1 so far
# 7. e - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 336), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of h\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "h" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 240), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 198), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 208), match='<reasoning>\nCounting the number of "j"\'s in the>
# *****Extract** 0
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "j"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "j"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "j"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "h" are there in the word "aperture"
# Answer: 0
# Response: <reasoning>
# Counting the number of "h" in the word "aperture"
# 1. a - 0 so far
# 2. p - 0 so far
# 3. e - 0 so far
# 4. a - 0 so far
# 5. p - 0 so far
# 6. t - 0 so far
# 7. r - 0 so far
# 8. u - 0 so far
# 9. e - 0 so far
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: True!
#
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 157), match='<reasoning>\nCounting the number of "w"\'s in the>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "w"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 156), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 192), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "a"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 188), match='<reasoning>\nCounting the number of "a" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "l" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 173), match='<reasoning>\nCounting the number of "l"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "w" are there in the word "glow"
# Answer: 1
# Response: <reasoning>
# Counting the number of "w"s in the word "glow"
# 1. g - 0 so far
# 2. l - 1 so far
# 3. o - 1 so far
# 4. w - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 170), match="<reasoning>\nCounting the number of n's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 180), match="<reasoning>\nCounting the number of n's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 167), match='<reasoning>\nCounting the number of "n"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 171), match="<reasoning>\nCounting the number of [letter_to_co>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "e" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 239), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 5
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "e"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "o"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 208), match='<reasoning>\nCounting the number of "o"\'s in the>
# *****Extract** 2
# <re.Match object; span=(0, 204), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 204), match="<reasoning>\nCounting the number of o's in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 141), match='<reasoning>\n1. g - 0 so far\n2. l - 0 so far\n3.>
# *****Extract** 1
# <re.Match object; span=(0, 204), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "s"s in the w>
# *****Extract** 1
#
# --------------------
# Question: How many of the letter "n" are there in the word "knack"
# Answer: 1
# Response: <reasoning>
# Counting the number of n's in the word knack
# 1. k - 0 so far
# 2. n - 1 so far
# 3. a - 1 so far
# 4. c - 1 so far
# 5. k - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>
# Extracted: 1
# Correct: True!
#
# <re.Match object; span=(0, 273), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "p"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "p" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "f" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 236), match='<reasoning>\nCounting the number of f\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "f" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 172), match='<reasoning>\nCounting the number of "f" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of "s" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 168), match="<reasoning>\nCounting the number of s's in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 155), match='<reasoning>\nCounting the number of s\'s in the w>
# *****Extract** 0
#
# --------------------
# Question: How many of the letter "p" are there in the word "eclipse"
# Answer: 1
# Response: <reasoning>
# Counting the number of "p"s in the word "eclipse"
# 1. e - 0 so far
# 2. l - 0 so far
# 3. c - 0 so far
# 4. p - 0 so far
# 5. l - 1 so far
# 6. c - 1 so far
# 7. e - 1 so far
# There are no occurrences of the letter "p" in the word "eclipse".
# </reasoning>
# <answer>
# 0
# </answer>
# Extracted: 0
# Correct: False!
#
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 4
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "c"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 280), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of t\'s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 0
# <re.Match object; span=(0, 240), match='<reasoning>\nCounting the number of "t"s in the w>
# *****Extract** 0
# <re.Match object; span=(0, 238), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "t"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 223), match='<reasoning>\nCounting the number of "t"\'s in the>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "t" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "t"s in the w>
# *****Extract** 2
#
# --------------------
# Question: How many of the letter "c" are there in the word "capture"
# Answer: 1
# Response: <reasoning>
# Counting the number of "c"s in the word "capture"
# 1. c - 1 so far
# 2. a - 1 no change
# 3. p - 1 no change
# 4. c - 2 so far
# 5. a - 2 no change
# 6. t - 2 no change
# 7. e - 3 no change
# </reasoning>
# <answer>
# 3
# </answer>
# Extracted: 3
# Correct: False!
#
# <re.Match object; span=(0, 222), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 207), match='<reasoning>\nCounting the number of "i"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 241), match='<reasoning>\nCounting the number of "i" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of u\'s in the w>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 197), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "u" in the wo>
# *****Extract** 1
# <re.Match object; span=(0, 206), match='<reasoning>\nCounting the number of "r"s in the w>
# *****Extract** 3
# <re.Match object; span=(0, 157), match='<reasoning>\n1. r - 1 so far\n2. a - 1 so far\n3.>
# *****Extract** 3
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "r" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 203), match="<reasoning>\nCounting the number of r's in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 221), match='<reasoning>\nCounting the number of "n" in the wo>
# *****Extract** 3
# <re.Match object; span=(0, 190), match='<reasoning>\nCounting the number of "n"s in the w>
# *****Extract** 2
# <re.Match object; span=(0, 189), match='<reasoning>\nCounting the number of "n" in the wo>
# *****Extract** 2
# <re.Match object; span=(0, 205), match='<reasoning>\nCounting the number of "n" in the wo>
# *****Extract** 3
#
# --------------------
# Question: How many of the letter "i" are there in the word "gossipy"
# Answer: 1
# Response: <reasoning>
# Counting the number of "i" in the word "gossipy"
# 1. g - 0 so far
# 2. o - 0 so far
# 3. s - 0 so far
# 4. s - 0 so far
# 5. p - 0 so far
# 6. y - 0 so far
# 7. y - 1 so far
# 8. i - 1 so far
# </reasoning>
# <answer>
# 2
# </answer>
# Extracted: 2
# Correct: False!

# %%
# Show the total (sum) of the rewards as well as the correct_answer_reward_func (means with in the batch)
# Do you see the rewards increasing? Does the model get the correct answer
# more frequently toward the end?
# No changes needed in this cell

import pandas as pd
import matplotlib.pyplot as plt

# If you want to graph other columns, check these out
print(f"available columns: {trainer.state.log_history[0].keys()}")

log_df = pd.DataFrame(trainer.state.log_history)
log_df["reward"].plot()
log_df["rewards/correct_answer_reward_func/mean"].plot()

# Show the legend
plt.legend(["reward", "rewards/correct_answer_reward_func/mean"])
plt.show()
# Out:
# available columns: dict_keys(['loss', 'grad_norm', 'learning_rate', 'num_tokens', 'completions/mean_length', 'completions/min_length', 'completions/max_length', 'completions/clipped_ratio', 'completions/mean_terminated_length', 'completions/min_terminated_length', 'completions/max_terminated_length', 'rewards/numbering_reward_func/mean', 'rewards/numbering_reward_func/std', 'rewards/spelling_reward_func/mean', 'rewards/spelling_reward_func/std', 'rewards/counting_reward_func/mean', 'rewards/counting_reward_func/std', 'rewards/format_reward_func/mean', 'rewards/format_reward_func/std', 'rewards/correct_answer_reward_func/mean', 'rewards/correct_answer_reward_func/std', 'reward', 'reward_std', 'frac_reward_zero_std', 'completion_length', 'kl', 'epoch', 'step'])

# %% [markdown]
# ## View the results
# Now let's try the model we just trained!

# %%
# Save the LoRA adapters
# No changes needed in this cell

# Save the LoRA model
model.save_lora("grpo_saved_lora")

# %%
# Create a function to run both the original model and the updated model
# No changes needed in this cell


def compare_old_and_new_model(messages):
    from vllm import SamplingParams

    text = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )

    sampling_params = SamplingParams(
        temperature=0.8,
        top_p=0.95,
        max_tokens=1024,
    )
    old = (
        model.fast_generate(
            text,
            sampling_params=sampling_params,
        )[0]
        .outputs[0]
        .text
    )

    new = (
        model.fast_generate(
            text,
            sampling_params=sampling_params,
            lora_request=model.load_lora("grpo_saved_lora"),
        )[0]
        .outputs[0]
        .text
    )

    print("===OLD===\n")
    print(old)

    print("\n\n===NEW===\n")
    print(new)

# %% [markdown]
# ### Compare the old and new models on the letter-counting task

# %%
# Let's try spelling the first word from the dataset
# TODO: Fill out the areas where you find **********

# Load the first item from the dataset (index 0) and compare the old and new models
print(ds[0]["prompt"])
compare_old_and_new_model(ds[0]["prompt"])
# Out:
# [{'content': "\nRespond in the following format:\n<reasoning>\nCounting the number of [letter_to_count]'s in the word [word]\n1. [first letter] - [count of requested letter so far] so far\n2. [second letter] - [count of requested letter so far] so far\n...\n</reasoning>\n<answer>\n[number]\n</answer>\n", 'role': 'system'}, {'content': 'How many of the letter "a" are there in the word "idea"', 'role': 'user'}]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 922.03it/s]
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it, est. speed input: 61.28 toks/s, output: 37.93 toks/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 841.89it/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it, est. speed input: 50.99 toks/s, output: 32.54 toks/s]
# ===OLD===
#
# <reasoning>
# Counting the number of a's in the word idea
# 1. i - 0 so far
# 2. d - 1 so far
# 3. e - 2 so far
# 4. a - 3 so far
# </reasoning>
# <answer>
# 3
# </answer>
#
#
# ===NEW===
#
# <reasoning>
# Counting the number of "a"s in the word "idea"
# 1. i - 0 so far
# 2. d - 0 so far
# 3. e - 0 so far
# 4. a - 1 so far
# </reasoning>
# <answer>
# 1
# </answer>

# %% [markdown]
# Our model is better at spelling and counter letters in words! Depending on your reward functions, the size of your model, and the amount of steps trained, results may vary.
#
# For about an hour of training time, your model may not be perfect (or maybe it is), but it's definitely moving in the right direction!

# %% [markdown]
# ### Make sure the model did not forget basic facts

# %%
# Let's see if the model still remembers some of the facts from its original training
# TODO: Fill out the areas where you find **********

# Ask both the old and new models a question the model is likely to know,
# e.g. a well-known capital city
compare_old_and_new_model([{"content":"The capital city of [country] is:","role":"system"},{"content":"What is the capital of the India?","role":"user"}])
# Out:
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1122.37it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.61it/s, est. speed input: 78.62 toks/s, output: 23.58 toks/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1183.49it/s]
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s, est. speed input: 69.65 toks/s, output: 20.89 toks/s]
# ===OLD===
#
# The capital of India is New Delhi.
#
#
# ===NEW===
#
# The capital of India is New Delhi.

# %% [markdown]
# Great job! Congrats on completing the project! 🎉🤗
